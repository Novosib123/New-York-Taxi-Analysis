# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
taxi_jan_2019 = pd.read_parquet('data/yellow_tripdata_2019-01.parquet')
taxi_data = pd.concat([taxi_jan_2019])

# %%
print(taxi_data.shape)
taxi_data.head()
# Out:
# (7696617, 19)
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2019-01-01 00:46:40   2019-01-01 00:53:20              1.0
# 1         1  2019-01-01 00:59:47   2019-01-01 01:18:59              1.0
# 2         2  2018-12-21 13:48:30   2018-12-21 13:52:40              3.0
# 3         2  2018-11-28 15:52:25   2018-11-28 15:55:45              5.0
# 4         2  2018-11-28 15:56:57   2018-11-28 15:58:33              5.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            1.5         1.0                  N           151           239
# 1            2.6         1.0                  N           239           246
# 2            0.0         1.0                  N           236           236
# 3            0.0         1.0                  N           193           193
# 4            0.0         2.0                  N           193           193
#
# ...

# %%
taxi_data.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'airport_fee'],
#       dtype='object')

# %%
taxi_data = taxi_data[['tpep_pickup_datetime', 'tpep_dropoff_datetime', 'passenger_count', 'trip_distance', 'RatecodeID','PULocationID', 'DOLocationID', 'payment_type', 'total_amount']]

# %%
taxi_data.head()
# Out:
#   tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  trip_distance  \
# 0  2019-01-01 00:46:40   2019-01-01 00:53:20              1.0            1.5
# 1  2019-01-01 00:59:47   2019-01-01 01:18:59              1.0            2.6
# 2  2018-12-21 13:48:30   2018-12-21 13:52:40              3.0            0.0
# 3  2018-11-28 15:52:25   2018-11-28 15:55:45              5.0            0.0
# 4  2018-11-28 15:56:57   2018-11-28 15:58:33              5.0            0.0
#
#    RatecodeID  PULocationID  DOLocationID  payment_type  total_amount
# 0         1.0           151           239             1          9.95
# 1         1.0           239           246             1         16.30
# 2         1.0           236           236             1          5.80
# 3         1.0           193           193             2          7.55
# 4         2.0           193           193             2         55.55

# %%
taxi_data.hist(figsize=(20, 10), bins= 60)
# Out:
# array([[<AxesSubplot:title={'center':'tpep_pickup_datetime'}>,
#         <AxesSubplot:title={'center':'tpep_dropoff_datetime'}>,
#         <AxesSubplot:title={'center':'passenger_count'}>],
#        [<AxesSubplot:title={'center':'trip_distance'}>,
#         <AxesSubplot:title={'center':'RatecodeID'}>,
#         <AxesSubplot:title={'center':'PULocationID'}>],
#        [<AxesSubplot:title={'center':'DOLocationID'}>,
#         <AxesSubplot:title={'center':'payment_type'}>,
#         <AxesSubplot:title={'center':'total_amount'}>]], dtype=object)

# %%
taxi_data.reset_index().plot(kind='scatter', y='total_amount', x='index', figsize=(16,8))
# Out:
# <AxesSubplot:xlabel='index', ylabel='total_amount'>

# %%
taxi_data[taxi_data['total_amount']<1000].reset_index().plot(kind='scatter', y='total_amount', x='index', figsize=(16,8))
# Out:
# <AxesSubplot:xlabel='index', ylabel='total_amount'>

# %%
print(taxi_data[taxi_data['total_amount']<0].shape)
# Out:
# (7127, 9)

# %%
taxi_data[taxi_data['total_amount']<0].reset_index().plot(kind='scatter', y='total_amount', x='index', figsize=(16,8))
# Out:
# <AxesSubplot:xlabel='index', ylabel='total_amount'>

# %%
taxi_data[taxi_data['total_amount']<0].head()
# Out:
#      tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 663   2019-01-01 00:32:56   2019-01-01 00:33:35              2.0
# 2402  2019-01-01 00:14:18   2019-01-01 00:40:55              1.0
# 2541  2019-01-01 00:31:27   2019-01-01 00:42:39              1.0
# 2544  2019-01-01 00:45:57   2019-01-01 00:46:07              1.0
# 2547  2019-01-01 00:48:35   2019-01-01 00:49:59              1.0
#
#       trip_distance  RatecodeID  PULocationID  DOLocationID  payment_type  \
# 663            0.10         1.0           148           148             3
# 2402           4.13         1.0           170           238             4
# 2541           1.35         1.0           162           234             4
# 2544           0.00         1.0           234           234             4
# 2547           0.16         1.0           234           234             4
#
#       total_amount
# 663           -3.8
# 2402         -20.3
# 2541          -9.8
# 2544          -3.8
# 2547          -4.3

# %%
taxi_data[taxi_data['total_amount']<0]['payment_type'].value_counts()
# Out:
# 3    4083
# 4    2667
# 2     376
# 1       1
# Name: payment_type, dtype: int64

# %%
taxi_data[taxi_data['total_amount']<0]['trip_distance'].hist(bins=60, figsize=(16,8))
# Out:
# <AxesSubplot:>

# %%
print(taxi_data[taxi_data['total_amount']==0].shape)
# Out:
# (1643, 9)

# %%
taxi_data[taxi_data['total_amount']==0].head()
# Out:
#       tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 3552   2019-01-01 00:18:46   2019-01-01 00:18:46              1.0
# 9138   2019-01-01 00:41:47   2019-01-01 00:41:47              1.0
# 13256  2019-01-01 00:19:38   2019-01-01 00:20:35              1.0
# 13257  2019-01-01 00:43:34   2019-01-01 00:43:34              1.0
# 13258  2019-01-01 00:02:52   2019-01-01 00:02:52              1.0
#
#        trip_distance  RatecodeID  PULocationID  DOLocationID  payment_type  \
# 3552             0.0         5.0           186           264             2
# 9138             0.0         5.0           246           264             2
# 13256            0.0         1.0           193           193             1
# 13257            0.0         1.0             7             7             2
# 13258            0.0         1.0           264             7             2
#
#        total_amount
# 3552            0.0
# 9138            0.0
# 13256           0.0
# 13257           0.0
# ...

# %%
taxi_data[taxi_data['total_amount'] == 0]['payment_type'].value_counts()
# Out:
# 1    813
# 2    569
# 0    231
# 3     29
# 4      1
# Name: payment_type, dtype: int64

# %%
taxi_data[taxi_data['total_amount']==0]['trip_distance'].hist(bins=60, figsize=(16,8))
# Out:
# <AxesSubplot:>

# %%
taxi_data[taxi_data['total_amount']==0]['trip_distance'].value_counts()
# Out:
# 0.00     1323
# 0.03        9
# 0.01        8
# 0.06        6
# 0.09        4
#          ...
# 4.79        1
# 0.16        1
# 20.59       1
# 3.34        1
# 4.48        1
# Name: trip_distance, Length: 256, dtype: int64

# %%
taxi_data[taxi_data['total_amount']>300].shape
# Out:
# (307, 9)

# %%
taxi_data['total_amount'].mean()
# Out:
# 15.810651344610214

# %% [markdown]
# **Data Cleaning**

# %%
taxi_data_filtered = taxi_data[(taxi_data['total_amount']>=0)&(taxi_data['total_amount']<200)&(taxi_data['passenger_count'].notna())]
taxi_data.shape
# Out:
# (7696617, 9)

# %%
taxi_data_filtered.head()
# Out:
#   tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  trip_distance  \
# 0  2019-01-01 00:46:40   2019-01-01 00:53:20              1.0            1.5
# 1  2019-01-01 00:59:47   2019-01-01 01:18:59              1.0            2.6
# 2  2018-12-21 13:48:30   2018-12-21 13:52:40              3.0            0.0
# 3  2018-11-28 15:52:25   2018-11-28 15:55:45              5.0            0.0
# 4  2018-11-28 15:56:57   2018-11-28 15:58:33              5.0            0.0
#
#    RatecodeID  PULocationID  DOLocationID  payment_type  total_amount
# 0         1.0           151           239             1          9.95
# 1         1.0           239           246             1         16.30
# 2         1.0           236           236             1          5.80
# 3         1.0           193           193             2          7.55
# 4         2.0           193           193             2         55.55

# %%
taxi_data_filtered.isna().sum()
# Out:
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# PULocationID             0
# DOLocationID             0
# payment_type             0
# total_amount             0
# dtype: int64

# %% [markdown]
# # 4. Data Preparation

# %%
taxi_data_prepared = taxi_data_filtered.copy()

# %%
taxi_data_prepared.dtypes
# Out:
# tpep_pickup_datetime     datetime64[ns]
# tpep_dropoff_datetime    datetime64[ns]
# passenger_count                 float64
# trip_distance                   float64
# RatecodeID                      float64
# PULocationID                      int64
# DOLocationID                      int64
# payment_type                      int64
# total_amount                    float64
# dtype: object

# %%
taxi_data_prepared.loc[:,'RatecodeID'] = taxi_data_prepared['RatecodeID'].astype(str)
taxi_data_prepared.loc[:,'PULocationID'] = taxi_data_prepared['PULocationID'].astype(str)
taxi_data_prepared.loc[:,'DOLocationID'] = taxi_data_prepared['DOLocationID'].astype(str)
taxi_data_prepared.loc[:,'payment_type'] = taxi_data_prepared['payment_type'].astype(str)
taxi_data_prepared.loc[:,'passenger_count'] = taxi_data_prepared['passenger_count'].astype(int)

# %%
taxi_data_prepared.dtypes
# Out:
# tpep_pickup_datetime     datetime64[ns]
# tpep_dropoff_datetime    datetime64[ns]
# passenger_count                   int32
# trip_distance                   float64
# RatecodeID                       object
# PULocationID                     object
# DOLocationID                     object
# payment_type                     object
# total_amount                    float64
# dtype: object

# %%
taxi_data_prepared.head()
# Out:
#   tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  trip_distance  \
# 0  2019-01-01 00:46:40   2019-01-01 00:53:20                1            1.5
# 1  2019-01-01 00:59:47   2019-01-01 01:18:59                1            2.6
# 2  2018-12-21 13:48:30   2018-12-21 13:52:40                3            0.0
# 3  2018-11-28 15:52:25   2018-11-28 15:55:45                5            0.0
# 4  2018-11-28 15:56:57   2018-11-28 15:58:33                5            0.0
#
#   RatecodeID PULocationID DOLocationID payment_type  total_amount
# 0        1.0          151          239            1          9.95
# 1        1.0          239          246            1         16.30
# 2        1.0          236          236            1          5.80
# 3        1.0          193          193            2          7.55
# 4        2.0          193          193            2         55.55

# %%
taxi_data_prepared['transaction_date'] = pd.to_datetime(taxi_data_prepared['tpep_pickup_datetime'].dt.date)

# %%
taxi_data_prepared.head()
# Out:
#   tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  trip_distance  \
# 0  2019-01-01 00:46:40   2019-01-01 00:53:20                1            1.5
# 1  2019-01-01 00:59:47   2019-01-01 01:18:59                1            2.6
# 2  2018-12-21 13:48:30   2018-12-21 13:52:40                3            0.0
# 3  2018-11-28 15:52:25   2018-11-28 15:55:45                5            0.0
# 4  2018-11-28 15:56:57   2018-11-28 15:58:33                5            0.0
#
#   RatecodeID PULocationID DOLocationID payment_type  total_amount  \
# 0        1.0          151          239            1          9.95
# 1        1.0          239          246            1         16.30
# 2        1.0          236          236            1          5.80
# 3        1.0          193          193            2          7.55
# 4        2.0          193          193            2         55.55
#
#   transaction_date
# 0       2019-01-01
# 1       2019-01-01
# 2       2018-12-21
# 3       2018-11-28
# ...

# %%
taxi_data_prepared['transaction_year'] = pd.DatetimeIndex(taxi_data_prepared['tpep_pickup_datetime']).year

# %%
taxi_data_prepared.head()
# Out:
#   tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  trip_distance  \
# 0  2019-01-01 00:46:40   2019-01-01 00:53:20                1            1.5
# 1  2019-01-01 00:59:47   2019-01-01 01:18:59                1            2.6
# 2  2018-12-21 13:48:30   2018-12-21 13:52:40                3            0.0
# 3  2018-11-28 15:52:25   2018-11-28 15:55:45                5            0.0
# 4  2018-11-28 15:56:57   2018-11-28 15:58:33                5            0.0
#
#   RatecodeID PULocationID DOLocationID payment_type  total_amount  \
# 0        1.0          151          239            1          9.95
# 1        1.0          239          246            1         16.30
# 2        1.0          236          236            1          5.80
# 3        1.0          193          193            2          7.55
# 4        2.0          193          193            2         55.55
#
#   transaction_date  transaction_year
# 0       2019-01-01              2019
# ...

# %%
taxi_data_prepared['transaction_month'] = pd.DatetimeIndex(taxi_data_prepared['tpep_pickup_datetime']).month
taxi_data_prepared['transaction_day'] = pd.DatetimeIndex(taxi_data_prepared['tpep_pickup_datetime']).day
taxi_data_prepared['transaction_hour'] = pd.DatetimeIndex(taxi_data_prepared['tpep_pickup_datetime']).hour

# %%
taxi_data_prepared.head()
# Out:
#   tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  trip_distance  \
# 0  2019-01-01 00:46:40   2019-01-01 00:53:20                1            1.5
# 1  2019-01-01 00:59:47   2019-01-01 01:18:59                1            2.6
# 2  2018-12-21 13:48:30   2018-12-21 13:52:40                3            0.0
# 3  2018-11-28 15:52:25   2018-11-28 15:55:45                5            0.0
# 4  2018-11-28 15:56:57   2018-11-28 15:58:33                5            0.0
#
#   RatecodeID PULocationID DOLocationID payment_type  total_amount  \
# 0        1.0          151          239            1          9.95
# 1        1.0          239          246            1         16.30
# 2        1.0          236          236            1          5.80
# 3        1.0          193          193            2          7.55
# 4        2.0          193          193            2         55.55
#
#   transaction_date  transaction_year  transaction_month  transaction_day  \
# ...

# %%
taxi_data_prepared = taxi_data_prepared[taxi_data_prepared['transaction_year'] == 2019]
taxi_data_prepared = taxi_data_prepared[taxi_data_prepared['transaction_month'] == 1]

# %%
taxi_data_prepared.head()
# Out:
#   tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  trip_distance  \
# 0  2019-01-01 00:46:40   2019-01-01 00:53:20                1            1.5
# 1  2019-01-01 00:59:47   2019-01-01 01:18:59                1            2.6
# 7  2019-01-01 00:21:28   2019-01-01 00:28:37                1            1.3
# 8  2019-01-01 00:32:01   2019-01-01 00:45:39                1            3.7
# 9  2019-01-01 00:57:32   2019-01-01 01:09:32                2            2.1
#
#   RatecodeID PULocationID DOLocationID payment_type  total_amount  \
# 0        1.0          151          239            1          9.95
# 1        1.0          239          246            1         16.30
# 7        1.0          163          229            1          9.05
# 8        1.0          229            7            1         18.50
# 9        1.0          141          234            1         13.00
#
#   transaction_date  transaction_year  transaction_month  transaction_day  \
# ...

# %%
taxi_data_prepared.shape
taxi_data_prepared.columns
# Out:
# Index(['tpep_pickup_datetime', 'tpep_dropoff_datetime', 'passenger_count',
#        'trip_distance', 'RatecodeID', 'PULocationID', 'DOLocationID',
#        'payment_type', 'total_amount', 'transaction_date', 'transaction_year',
#        'transaction_month', 'transaction_day', 'transaction_hour'],
#       dtype='object')

# %%
categorical_columns = ['PULocationID', 'transaction_date', 'transaction_month', 'transaction_day', 'transaction_hour']
numerical_coulumns = ['trip_distance', 'total_amount']
all_needed_columns = categorical_columns + numerical_coulumns

# %%
all_needed_columns
# Out:
# ['PULocationID',
#  'transaction_date',
#  'transaction_month',
#  'transaction_day',
#  'transaction_hour',
#  'trip_distance',
#  'total_amount']

# %%
main_taxi_df = taxi_data_prepared[all_needed_columns]
print(main_taxi_df.shape)
main_taxi_df.head()
# Out:
# (7659111, 7)
#   PULocationID transaction_date  transaction_month  transaction_day  \
# 0          151       2019-01-01                  1                1
# 1          239       2019-01-01                  1                1
# 7          163       2019-01-01                  1                1
# 8          229       2019-01-01                  1                1
# 9          141       2019-01-01                  1                1
#
#    transaction_hour  trip_distance  total_amount
# 0                 0            1.5          9.95
# 1                 0            2.6         16.30
# 7                 0            1.3          9.05
# 8                 0            3.7         18.50
# 9                 0            2.1         13.00

# %% [markdown]
# Aggregate data points
# Now is a good time to think about what we want to predict. Depending on this we need to transform our data to have certain format

# %%
taxi_grouped_by_region = main_taxi_df.groupby(categorical_columns).mean().reset_index()
taxi_grouped_by_region['count_of_transactions'] = main_taxi_df.groupby(categorical_columns).count().reset_index()['total_amount']
print(taxi_grouped_by_region.shape)
taxi_grouped_by_region.head()
# Out:
# (102496, 8)
#   PULocationID transaction_date  transaction_month  transaction_day  \
# 0            1       2019-01-01                  1                1
# 1            1       2019-01-01                  1                1
# 2            1       2019-01-01                  1                1
# 3            1       2019-01-01                  1                1
# 4            1       2019-01-01                  1                1
#
#    transaction_hour  trip_distance  total_amount  count_of_transactions
# 0                 2            0.0        21.800                      1
# 1                 5            0.0        87.300                      1
# 2                 6            0.0        80.300                      1
# 3                 8            0.0       128.580                      2
# 4                10           16.9        43.245                      4

# %% [markdown]
# 5. Benchmark model

# %%
data_for_benchmark_model = taxi_grouped_by_region.copy()

# %%
categorical_features_benchmark = ['PULocationID', 'transaction_month', 'transaction_day', 'transaction_hour']
input_features_benchmark = categorical_features_benchmark #+ ['trip_distance']
target_feature_benchmark = 'total_amount'

# %%
from sklearn.model_selection import train_test_split

X_bench = data_for_benchmark_model[input_features_benchmark]
y_bench = data_for_benchmark_model[target_feature_benchmark]

X_bench = pd.get_dummies(X_bench)
X_train_b, X_test_b, y_train_b, y_test_b = train_test_split(X_bench, y_bench, test_size=0.33)

# %% [markdown]
# 5.2 Fit model to data

# %%
from sklearn.tree import DecisionTreeRegressor

tree = DecisionTreeRegressor(max_depth=10)
tree.fit(X_train_b, y_train_b)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=10,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %% [markdown]
# 5.3 Model evaluation

# %%
model_at_hand = tree

y_pred_b = model_at_hand.predict(X_test_b)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from math import sqrt

print('mean_absolute_error', mean_absolute_error(y_test_b, y_pred_b))
print('mean_squared_error', mean_squared_error(y_test_b, y_pred_b))
print('root_mean_squared_error', sqrt(mean_squared_error(y_test_b, y_pred_b)))
print('r2', r2_score(y_test_b, y_pred_b))
# Out:
# mean_absolute_error 9.797135919386706
# mean_squared_error 216.05529051009714
# root_mean_squared_error 14.698819357693226
# r2 0.21404069652636137

# %%
data = {'true': y_test_b, 'pred': y_pred_b}
results = pd.DataFrame(data)

results.plot(figsize=(20,10), kind='scatter', x='true', y='pred')
# Out:
# <AxesSubplot:xlabel='true', ylabel='pred'>

# %% [markdown]
# 6. Feature engineering

# %%
taxi_grouped_by_region.head()
# Out:
#   PULocationID transaction_date  transaction_month  transaction_day  \
# 0            1       2019-01-01                  1                1
# 1            1       2019-01-01                  1                1
# 2            1       2019-01-01                  1                1
# 3            1       2019-01-01                  1                1
# 4            1       2019-01-01                  1                1
#
#    transaction_hour  trip_distance  total_amount  count_of_transactions
# 0                 2            0.0        21.800                      1
# 1                 5            0.0        87.300                      1
# 2                 6            0.0        80.300                      1
# 3                 8            0.0       128.580                      2
# 4                10           16.9        43.245                      4

# %%
data_with_new_features = taxi_grouped_by_region.copy()

# %% [markdown]
# Date-related features

# %%
data_with_new_features['transaction_week_day'] = data_with_new_features['transaction_date'].dt.weekday
data_with_new_features['weekend'] = data_with_new_features['transaction_week_day'].apply(lambda x: True if x == 5 or x == 6 else False)

# %%
data_with_new_features.head()
# Out:
#   PULocationID transaction_date  transaction_month  transaction_day  \
# 0            1       2019-01-01                  1                1
# 1            1       2019-01-01                  1                1
# 2            1       2019-01-01                  1                1
# 3            1       2019-01-01                  1                1
# 4            1       2019-01-01                  1                1
#
#    transaction_hour  trip_distance  total_amount  count_of_transactions  \
# 0                 2            0.0        21.800                      1
# 1                 5            0.0        87.300                      1
# 2                 6            0.0        80.300                      1
# 3                 8            0.0       128.580                      2
# 4                10           16.9        43.245                      4
#
#    transaction_week_day  weekend
# 0                     1    False
# 1                     1    False
# ...

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar
cal = USFederalHolidayCalendar()
holidays = cal.holidays(start='2018',end='2020').date
data_with_new_features['is_holiday'] = data_with_new_features['transaction_date'].isin(holidays)

# %%
data_with_new_features.head()
# Out:
#   PULocationID transaction_date  transaction_month  transaction_day  \
# 0            1       2019-01-01                  1                1
# 1            1       2019-01-01                  1                1
# 2            1       2019-01-01                  1                1
# 3            1       2019-01-01                  1                1
# 4            1       2019-01-01                  1                1
#
#    transaction_hour  trip_distance  total_amount  count_of_transactions  \
# 0                 2            0.0        21.800                      1
# 1                 5            0.0        87.300                      1
# 2                 6            0.0        80.300                      1
# 3                 8            0.0       128.580                      2
# 4                10           16.9        43.245                      4
#
#    transaction_week_day  weekend  is_holiday
# 0                     1    False        True
# ...

# %% [markdown]
# Borough information

# %%
zone_lookup = pd.read_csv('data/taxi_zone_lookup.csv')
zone_lookup = zone_lookup[['LocationID', 'Borough']]
zone_lookup['LocationID'] = zone_lookup['LocationID'].astype(str)
zone_lookup.head()
# Out:
#   LocationID        Borough
# 0          1            EWR
# 1          2         Queens
# 2          3          Bronx
# 3          4      Manhattan
# 4          5  Staten Island

# %%
data_with_new_features.head()
# Out:
#   PULocationID transaction_date  transaction_month  transaction_day  \
# 0            1       2019-01-01                  1                1
# 1            1       2019-01-01                  1                1
# 2            1       2019-01-01                  1                1
# 3            1       2019-01-01                  1                1
# 4            1       2019-01-01                  1                1
#
#    transaction_hour  trip_distance  total_amount  count_of_transactions  \
# 0                 2            0.0        21.800                      1
# 1                 5            0.0        87.300                      1
# 2                 6            0.0        80.300                      1
# 3                 8            0.0       128.580                      2
# 4                10           16.9        43.245                      4
#
#    transaction_week_day  weekend  is_holiday
# 0                     1    False        True
# ...

# %%
data_with_new_features_merge = data_with_new_features.copy(data)

# %%
data_with_new_features_merge = data_with_new_features.merge(zone_lookup, left_on='PULocationID', right_on='LocationID', how='left')
data_with_new_features_merge.head()
# Out:
#   PULocationID transaction_date  transaction_month  transaction_day  \
# 0            1       2019-01-01                  1                1
# 1            1       2019-01-01                  1                1
# 2            1       2019-01-01                  1                1
# 3            1       2019-01-01                  1                1
# 4            1       2019-01-01                  1                1
#
#    transaction_hour  trip_distance  total_amount  count_of_transactions  \
# 0                 2            0.0        21.800                      1
# 1                 5            0.0        87.300                      1
# 2                 6            0.0        80.300                      1
# 3                 8            0.0       128.580                      2
# 4                10           16.9        43.245                      4
#
#    transaction_week_day  weekend  is_holiday LocationID Borough
# ...

# %%
data_with_new_features = data_with_new_features_merge
data_with_new_features.head()
# Out:
#   PULocationID transaction_date  transaction_month  transaction_day  \
# 0            1       2019-01-01                  1                1
# 1            1       2019-01-01                  1                1
# 2            1       2019-01-01                  1                1
# 3            1       2019-01-01                  1                1
# 4            1       2019-01-01                  1                1
#
#    transaction_hour  trip_distance  total_amount  count_of_transactions  \
# 0                 2            0.0        21.800                      1
# 1                 5            0.0        87.300                      1
# 2                 6            0.0        80.300                      1
# 3                 8            0.0       128.580                      2
# 4                10           16.9        43.245                      4
#
#    transaction_week_day  weekend  is_holiday LocationID Borough
# ...

# %%
data_with_new_features['Borough'].value_counts()
# Out:
# Manhattan        45309
# Brooklyn         23633
# Queens           21942
# Bronx             9586
# Unknown           1453
# Staten Island      302
# EWR                271
# Name: Borough, dtype: int64

# %% [markdown]
# Weather related features

# %%
nyc_weather = pd.read_csv('data/nyc_weather.csv')
nyc_weather.head()
# Out:
#       date and time  temperature  humidity  wind speed cloud cover  \
# 0  31.12.2019 22:00          6.1        65           6       100%.
# 1  31.12.2019 19:00          6.7        71           5   70 – 80%.
# 2  31.12.2019 16:00          7.2        66           5        50%.
# 3  31.12.2019 13:00          6.1        76           3       100%.
# 4  31.12.2019 10:00          4.4        83           2       100%.
#
#   amount of precipitation
# 0                     0.3
# 1                     NaN
# 2                     NaN
# 3  Trace of precipitation
# 4  Trace of precipitation

# %%
nyc_weather.dtypes
# Out:
# date and time               object
# temperature                float64
# humidity                     int64
# wind speed                   int64
# cloud cover                 object
# amount of precipitation     object
# dtype: object

# %%
nyc_weather['cloud cover'].value_counts()
# Out:
# 70 – 80%.                                                     973
# 100%.                                                         896
# 20–30%.                                                       479
# 50%.                                                          413
# no clouds                                                     168
# Sky obscured by fog and/or other meteorological phenomena.      3
# Name: cloud cover, dtype: int64

# %%
nyc_weather['amount of precipitation'].value_counts()
# Out:
# Trace of precipitation    266
# 0.3                        61
# 2.0                        49
# 1.0                        45
# 0.8                        42
# 0.5                        42
# 4.0                        33
# 5.0                        24
# 3.0                        23
# 6.0                        19
# 7.0                        13
# 8.0                        13
# 9.0                        11
# 10.0                       10
# 13.0                        7
# 12.0                        7
# 15.0                        6
# 11.0                        5
# 16.0                        3
# 22.0                        2
# 29.0                        2
# 14.0                        2
# 21.0                        1
# 63.0                        1
# 18.0                        1
# 25.0                        1
# 68.0                        1
# 20.0                        1
# 17.0                        1
# 30.0                        1
# 24.0                        1
# ...

# %%
nyc_weather['amount of precipitation'] = nyc_weather['amount of precipitation'].replace('Trace of precipitation', 0.1) 
nyc_weather['amount of precipitation'] = nyc_weather['amount of precipitation'].astype(float)
nyc_weather['amount of precipitation'].interpolate(inplace=True)

# %%
nyc_weather['cloud cover'] = nyc_weather['cloud cover'].replace('70 – 80%.', 0.7)
nyc_weather['cloud cover'] = nyc_weather['cloud cover'].replace('100%.', 1)
nyc_weather['cloud cover'] = nyc_weather['cloud cover'].replace('20–30%.', 0.3)
nyc_weather['cloud cover'] = nyc_weather['cloud cover'].replace('50%.', 0.5)
nyc_weather['cloud cover'] = nyc_weather['cloud cover'].replace('no clouds', 0)
nyc_weather['cloud cover'] = nyc_weather['cloud cover'].replace('Sky obscured by fog and/or other meteorological phenomena.', 1)
nyc_weather['cloud cover'] = nyc_weather['cloud cover'].astype(float)
nyc_weather['cloud cover'].interpolate(inplace=True)

# %%
nyc_weather.dtypes
# Out:
# date and time               object
# temperature                float64
# humidity                     int64
# wind speed                   int64
# cloud cover                float64
# amount of precipitation    float64
# dtype: object

# %%
nyc_weather.loc[:,'date and time'] = pd.to_datetime(nyc_weather.loc[:,'date and time'])
nyc_weather['hour'] = nyc_weather['date and time'].dt.hour
nyc_weather['month'] = nyc_weather['date and time'].dt.month
nyc_weather['day'] = nyc_weather['date and time'].dt.day

# %%
nyc_weather.head()
# Out:
#         date and time  temperature  humidity  wind speed  cloud cover  \
# 0 2019-12-31 22:00:00          6.1        65           6          1.0
# 1 2019-12-31 19:00:00          6.7        71           5          0.7
# 2 2019-12-31 16:00:00          7.2        66           5          0.5
# 3 2019-12-31 13:00:00          6.1        76           3          1.0
# 4 2019-12-31 10:00:00          4.4        83           2          1.0
#
#    amount of precipitation  hour  month  day
# 0                 0.300000    22     12   31
# 1                 0.233333    19     12   31
# 2                 0.166667    16     12   31
# 3                 0.100000    13     12   31
# 4                 0.100000    10     12   31

# %%
nyc_taxi_with_weather = data_with_new_features.merge(nyc_weather, left_on = ['transaction_month','transaction_day','transaction_hour'], right_on = ['month','day','hour'], how='left')

print(nyc_taxi_with_weather.shape)
nyc_taxi_with_weather.head()
# Out:
# (102496, 22)
#   PULocationID transaction_date  transaction_month  transaction_day  \
# 0            1       2019-01-01                  1                1
# 1            1       2019-01-01                  1                1
# 2            1       2019-01-01                  1                1
# 3            1       2019-01-01                  1                1
# 4            1       2019-01-01                  1                1
#
#    transaction_hour  trip_distance  total_amount  count_of_transactions  \
# 0                 2            0.0        21.800                      1
# 1                 5            0.0        87.300                      1
# 2                 6            0.0        80.300                      1
# 3                 8            0.0       128.580                      2
# 4                10           16.9        43.245                      4
#
#    transaction_week_day  weekend  ...  Borough       date and time  \
# ...

# %%
nyc_taxi_with_weather = nyc_taxi_with_weather.drop(['date and time', 'hour', 'month', 'day'], axis=1)

# %%
nyc_taxi_with_weather.head()
# Out:
#   PULocationID transaction_date  transaction_month  transaction_day  \
# 0            1       2019-01-01                  1                1
# 1            1       2019-01-01                  1                1
# 2            1       2019-01-01                  1                1
# 3            1       2019-01-01                  1                1
# 4            1       2019-01-01                  1                1
#
#    transaction_hour  trip_distance  total_amount  count_of_transactions  \
# 0                 2            0.0        21.800                      1
# 1                 5            0.0        87.300                      1
# 2                 6            0.0        80.300                      1
# 3                 8            0.0       128.580                      2
# 4                10           16.9        43.245                      4
#
#    transaction_week_day  weekend  is_holiday LocationID Borough  temperature  \
# ...

# %%
nyc_taxi_with_weather.isna().sum()
# Out:
# PULocationID                   0
# transaction_date               0
# transaction_month              0
# transaction_day                0
# transaction_hour               0
# trip_distance                  0
# total_amount                   0
# count_of_transactions          0
# transaction_week_day           0
# weekend                        0
# is_holiday                     0
# LocationID                     0
# Borough                        0
# temperature                68334
# humidity                   68334
# wind speed                 68334
# cloud cover                68334
# amount of precipitation    68334
# dtype: int64

# %%
nyc_taxi_with_weather = nyc_taxi_with_weather.sort_values(['transaction_date','transaction_hour']).reset_index().drop('index',axis=1)

# %%
nyc_taxi_with_weather.head()
# Out:
#   PULocationID transaction_date  transaction_month  transaction_day  \
# 0           10       2019-01-01                  1                1
# 1          100       2019-01-01                  1                1
# 2          106       2019-01-01                  1                1
# 3          107       2019-01-01                  1                1
# 4           11       2019-01-01                  1                1
#
#    transaction_hour  trip_distance  total_amount  count_of_transactions  \
# 0                 0       3.020000     14.300000                      2
# 1                 0       2.801852     18.130000                     54
# 2                 0       2.593333     15.373333                      3
# 3                 0       2.437458     14.897458                    421
# 4                 0       1.795000      9.300000                      2
#
#    transaction_week_day  weekend  is_holiday LocationID    Borough  \
# ...

# %%
nyc_taxi_with_weather = nyc_taxi_with_weather.interpolate()
nyc_taxi_with_weather = nyc_taxi_with_weather.fillna(method='bfill')
nyc_taxi_with_weather.isna().sum()
# Out:
# PULocationID               0
# transaction_date           0
# transaction_month          0
# transaction_day            0
# transaction_hour           0
# trip_distance              0
# total_amount               0
# count_of_transactions      0
# transaction_week_day       0
# weekend                    0
# is_holiday                 0
# LocationID                 0
# Borough                    0
# temperature                0
# humidity                   0
# wind speed                 0
# cloud cover                0
# amount of precipitation    0
# dtype: int64

# %%
nyc_taxi_with_weather.head()
# Out:
#   PULocationID transaction_date  transaction_month  transaction_day  \
# 0           10       2019-01-01                  1                1
# 1          100       2019-01-01                  1                1
# 2          106       2019-01-01                  1                1
# 3          107       2019-01-01                  1                1
# 4           11       2019-01-01                  1                1
#
#    transaction_hour  trip_distance  total_amount  count_of_transactions  \
# 0                 0       3.020000     14.300000                      2
# 1                 0       2.801852     18.130000                     54
# 2                 0       2.593333     15.373333                      3
# 3                 0       2.437458     14.897458                    421
# 4                 0       1.795000      9.300000                      2
#
#    transaction_week_day  weekend  is_holiday LocationID    Borough  \
# ...

# %% [markdown]
# # 7. Model Training

# %%
data_for_model = nyc_taxi_with_weather.copy()

# %%
categorical_features = ['PULocationID', 'transaction_month', 'transaction_day',
       'transaction_hour', 'transaction_week_day', 'weekend', 'is_holiday', 'Borough']
input_features = categorical_features + ['temperature', 'humidity', 'wind speed', 'cloud cover',
       'amount of precipitation']
target_feature = 'total_amount'

# %%
from sklearn.model_selection import train_test_split

X = data_for_model[input_features]
y = data_for_model[target_feature]

# one-hot encode
X = pd.get_dummies(X)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# %%
from sklearn.tree import DecisionTreeRegressor 

decision_tree = DecisionTreeRegressor(max_depth=10)
decision_tree.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=10,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
model_at_hand = decision_tree

y_pred = model_at_hand.predict(X_test)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from math import sqrt

print('mean_absolute_error', mean_absolute_error(y_test, y_pred))
print('mean_squared_error', mean_squared_error(y_test, y_pred))
print('root_mean_squared_error', sqrt(mean_squared_error(y_test, y_pred)))
print('r2', r2_score(y_test, y_pred))
# Out:
# mean_absolute_error 8.511448226977091
# mean_squared_error 199.25962111697822
# root_mean_squared_error 14.115935006827504
# r2 0.2939568888309273

# %%
data = {'true': y_test, 'pred': y_pred}
results = pd.DataFrame(data)

results.plot(figsize=(20,10), kind='scatter', x='true', y='pred')
# Out:
# <AxesSubplot:xlabel='true', ylabel='pred'>

# %% [markdown]
# 7.2 Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
rando_model = RandomForestRegressor()
rando_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
model_at_hand = rando_model

y_pred = model_at_hand.predict(X_test)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from math import sqrt

print('mean_absolute_error', mean_absolute_error(y_test, y_pred))
print('mean_squared_error', mean_squared_error(y_test, y_pred))
print('root_mean_squared_error', sqrt(mean_squared_error(y_test, y_pred)))
print('r2', r2_score(y_test, y_pred))
# Out:
# mean_absolute_error 7.44785678515341
# mean_squared_error 175.32742375837077
# root_mean_squared_error 13.241126226963127
# r2 0.3787566238974902

# %%
data = {'true': y_test, 'pred': y_pred}
results = pd.DataFrame(data)

results.plot(figsize=(20,10), kind='scatter', x='true', y='pred')
# Out:
# <AxesSubplot:xlabel='true', ylabel='pred'>

# %% [markdown]
# 7.3 Gradient boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor

gradBooster = GradientBoostingRegressor()
gradBooster.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
model_at_hand = gradBooster

y_pred = model_at_hand.predict(X_test)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from math import sqrt

print('mean_absolute_error', mean_absolute_error(y_test, y_pred))
print('mean_squared_error', mean_squared_error(y_test, y_pred))
print('root_mean_squared_error', sqrt(mean_squared_error(y_test, y_pred)))
print('r2', r2_score(y_test, y_pred))
# Out:
# mean_absolute_error 8.32395041074604
# mean_squared_error 176.426609812895
# root_mean_squared_error 13.28256789227501
# r2 0.37486184211812335

# %%
data = {'true': y_test, 'pred': y_pred}
results = pd.DataFrame(data)

results.plot(figsize=(20,10), kind='scatter', x='true', y='pred')
# Out:
# <AxesSubplot:xlabel='true', ylabel='pred'>

# %%
(pd.Series(model_at_hand.feature_importances_, index=X_train.columns).nlargest(10).plot(kind='barh'))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 8. Tunning

# %% [markdown]
# 8.1 Find best parameters

# %%
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [10,20,50,100,150,200,300,500]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 20, 40]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4, 10, 20]
# Method of selecting samples for training each tree
bootstrap = [True, False]

# %%
import pprint as pp

# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}
pp.pprint(random_grid)
# Out:
# {'bootstrap': [True, False],
#  'max_depth': [10, 20, 50, 100, 150, 200, 300, 500, None],
#  'max_features': ['auto', 'sqrt'],
#  'min_samples_leaf': [1, 2, 4, 10, 20],
#  'min_samples_split': [2, 5, 10, 20, 40],
#  'n_estimators': [200, 400, 600, 800, 1000, 1200, 1400, 1600, 1800, 2000]}

# %%
from sklearn.model_selection import RandomizedSearchCV

rf = RandomForestRegressor()
rf_random = RandomizedSearchCV(estimator=rf, param_distributions= random_grid, n_iter=10, cv=3, verbose=2, n_jobs= -1)
rf_random.fit(X_train, y_train)
performances = pd.DataFrame.from_dict(rf_random.cv_results_)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  15 out of  30 | elapsed: 11.0min remaining: 11.0min
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed: 54.0min finished

# %%
performances
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      90.424527      0.258205         4.880283        0.095612
# 1      27.629144      0.443514         1.501161        0.037957
# 2      34.964450      0.459660         1.524335        0.073586
# 3     593.741196      3.149091         3.081455        0.153911
# 4    1319.149000     16.083792         6.121176        0.252163
# 5     570.393845      2.525642        23.312393        5.731786
# 6      86.662983      1.231820         2.430143        0.075372
# 7     319.351455      1.055397        19.316791        0.868931
# 8    2144.666230      3.673831        11.442098        0.963875
# 9     230.801725     13.396540         9.385748        2.349138
#
#   param_n_estimators param_min_samples_split param_min_samples_leaf  \
# 0                200                      10                      1
# 1                200                       5                      4
# ...

# %%
import time
t0 = time.time()

best = RandomForestRegressor(n_estimators=600, min_samples_split=10, min_samples_leaf=2, max_features='sqrt', max_depth=500, bootstrap=False)
best.fit(X_train, y_train)

t1 = time.time() - t0
print("Time elapsed: ", t1, " sconds")

model_at_hand = best

y_pred = model_at_hand.predict(X_test)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from math import sqrt

print('mean_absolute_error', mean_squared_error(y_test, y_pred))
print('mean_squared_error', mean_squared_error(y_test, y_pred))
print('root_mean_squared_error', sqrt(mean_squared_error(y_test, y_pred)))
print('r2', r2_score(y_test, y_pred))
# Out:
# Time elapsed:  136.4900975227356  sconds
# mean_absolute_error 161.18373076964167
# mean_squared_error 161.18373076964167
# root_mean_squared_error 12.695815482655759
# r2 0.42887243233476535
